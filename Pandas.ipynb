# %% [markdown]
# <a href="https://colab.research.google.com/github/farhadrahimiinfo/Machine_Learning/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Pandas
# Ref: https://pandas.pydata.org/docs/user_guide/10min.html

# %%
import pandas as pd
import numpy as np

# %%
pd.Series([1,2,3,'Farhad',0,np.nan,-10])
# Out:
# 0         1
# 1         2
# 2         3
# 3    Farhad
# 4         0
# 5       NaN
# 6       -10
# dtype: object

# %%
dates=pd.date_range('20240101',periods=6)
dates
# Out:
# DatetimeIndex(['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-04',
#                '2024-01-05', '2024-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
np.random.rand(6,4)
# Out:
# array([[0.10443739, 0.48197149, 0.63334465, 0.95615735],
#        [0.09533462, 0.57100767, 0.68989643, 0.33629109],
#        [0.06013644, 0.98644172, 0.02276326, 0.6037271 ],
#        [0.2150857 , 0.9185454 , 0.37561343, 0.93828785],
#        [0.67952548, 0.93135057, 0.9845195 , 0.98632045],
#        [0.70500883, 0.14703524, 0.35175236, 0.14618811]])

# %%
np.random.randn(6,4)
# Out:
# array([[ 1.34415729,  1.935262  ,  0.80291546,  1.09312965],
#        [ 0.20927903,  1.08913365, -1.86422128, -0.0756089 ],
#        [ 0.26625469,  1.15737989,  1.22666311,  0.20638492],
#        [-0.65880055, -0.9725425 ,  0.07716943, -1.88452875],
#        [ 0.00424058,  0.11135801, -0.42579548,  2.1776079 ],
#        [-1.33119033, -0.69127425, -0.75232237,  0.12120291]])

# %%
df=pd.DataFrame(np.random.randn(6,4),index=dates)
df
# Out:
#                    0         1         2         3
# 2024-01-01  1.450548 -0.281473 -1.812416 -0.633025
# 2024-01-02 -0.380758 -1.819315  0.427962 -0.516858
# 2024-01-03  0.294834 -0.465918 -0.392573  0.937313
# 2024-01-04 -0.182404  1.579830  0.314340 -1.668829
# 2024-01-05  1.413051 -0.902607 -1.721249 -0.008706
# 2024-01-06 -0.104172  1.472352 -1.200783 -1.406537
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df[0].plot(kind='hist', bins=20, title=0)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df[1].plot(kind='hist', bins=20, title=1)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df[2].plot(kind='hist', bins=20, title=2)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %%
df=pd.DataFrame(np.random.randn(6,4),index=dates,columns=["a","b","c","d"])
df
# Out:
#                    a         b         c         d
# 2024-01-01 -0.379919 -0.645925 -0.178026  1.593798
# 2024-01-02  0.637572 -0.426298 -0.662900 -1.428301
# 2024-01-03  0.043322 -0.515507  0.062746 -1.754389
# 2024-01-04  0.665775  1.474326 -0.944639 -1.794232
# 2024-01-05  0.797434 -1.039860 -0.130500  0.586605
# 2024-01-06  0.661480 -1.138577  0.647477 -0.728402

# %%
df.dtypes
# Out:
# a    float64
# b    float64
# c    float64
# d    float64
# dtype: object

# %%
df["a"]
# Out:
# 2024-01-01   -0.379919
# 2024-01-02    0.637572
# 2024-01-03    0.043322
# 2024-01-04    0.665775
# 2024-01-05    0.797434
# 2024-01-06    0.661480
# Freq: D, Name: a, dtype: float64

# %%
df.head
# Out:
# <bound method NDFrame.head of                    a         b         c         d
# 2024-01-01 -0.379919 -0.645925 -0.178026  1.593798
# 2024-01-02  0.637572 -0.426298 -0.662900 -1.428301
# 2024-01-03  0.043322 -0.515507  0.062746 -1.754389
# 2024-01-04  0.665775  1.474326 -0.944639 -1.794232
# 2024-01-05  0.797434 -1.039860 -0.130500  0.586605
# 2024-01-06  0.661480 -1.138577  0.647477 -0.728402>

# %%
df.head(2)
# Out:
#                    a         b         c         d
# 2024-01-01 -0.379919 -0.645925 -0.178026  1.593798
# 2024-01-02  0.637572 -0.426298 -0.662900 -1.428301

# %%
df.tail(2)
# Out:
#                    a         b         c         d
# 2024-01-05  0.797434 -1.039860 -0.130500  0.586605
# 2024-01-06  0.661480 -1.138577  0.647477 -0.728402

# %%
df.describe()
# Out:
#               a         b         c         d
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.404277 -0.381974 -0.200974 -0.587487
# std    0.466644  0.952951  0.558807  1.391489
# min   -0.379919 -1.138577 -0.944639 -1.794232
# 25%    0.191884 -0.941376 -0.541681 -1.672867
# 50%    0.649526 -0.580716 -0.154263 -1.078352
# 75%    0.664701 -0.448600  0.014435  0.257853
# max    0.797434  1.474326  0.647477  1.593798
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['a'].plot(kind='hist', bins=20, title='a')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['b'].plot(kind='hist', bins=20, title='b')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['c'].plot(kind='hist', bins=20, title='c')
# ...

# %%
df.mean()
# Out:
# a    0.404277
# b   -0.381974
# c   -0.200974
# d   -0.587487
# dtype: float64

# %%
df["a"].mean()
# Out:
# 0.4042773675001113

# %%
df[1:3]
# Out:
#                    a         b         c         d
# 2024-01-02  0.637572 -0.426298 -0.662900 -1.428301
# 2024-01-03  0.043322 -0.515507  0.062746 -1.754389

# %%
df.T
# Out:
#    2024-01-01  2024-01-02  2024-01-03  2024-01-04  2024-01-05  2024-01-06
# a   -0.379919    0.637572    0.043322    0.665775    0.797434    0.661480
# b   -0.645925   -0.426298   -0.515507    1.474326   -1.039860   -1.138577
# c   -0.178026   -0.662900    0.062746   -0.944639   -0.130500    0.647477
# d    1.593798   -1.428301   -1.754389   -1.794232    0.586605   -0.728402

# %%
df.sort_values(by="a")
# Out:
#                    a         b         c         d
# 2024-01-01 -0.379919 -0.645925 -0.178026  1.593798
# 2024-01-03  0.043322 -0.515507  0.062746 -1.754389
# 2024-01-02  0.637572 -0.426298 -0.662900 -1.428301
# 2024-01-06  0.661480 -1.138577  0.647477 -0.728402
# 2024-01-04  0.665775  1.474326 -0.944639 -1.794232
# 2024-01-05  0.797434 -1.039860 -0.130500  0.586605

# %%
df[df["b"]>1]
# Out:
#                    a         b         c         d
# 2024-01-04  0.665775  1.474326 -0.944639 -1.794232

# %% [markdown]
# ## read and write

# %%
df=pd.DataFrame(np.random.randn(6,4),index=dates,columns=["a","b","c","d"])
df
# Out:
#                    a         b         c         d
# 2024-01-01  0.192681  1.342413 -2.743285  1.673918
# 2024-01-02 -0.100584  1.077394 -0.867436  0.528481
# 2024-01-03 -1.152414  0.482068  0.877395  0.943060
# 2024-01-04  0.307178 -0.736110 -0.412355 -0.542380
# 2024-01-05 -0.753407  0.452757 -1.025894 -1.357675
# 2024-01-06 -2.127890  1.619556 -0.071381 -0.453394

# %%
df.to_csv('MyTemplate.csv')

# %%
# !pip install xlwt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.0/100.0 kB 2.1 MB/s eta 0:00:00
# ...

# %%
df.to_excel('MyTemplate.xls')
# Out:
# <ipython-input-51-40541520de63>:1: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   df.to_excel('MyTemplate.xls')
